# %%
# !pip install pyts
# !pip install --upgrade pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.23.5)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.3.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from pyts) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->pyts) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->pyts) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.0->pyts) (3.2.0)
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0
# Requirement already satisfied: pyts in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.23.5)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.3.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from pyts) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->pyts) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->pyts) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.0->pyts) (3.2.0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix,f1_score
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import sys
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from scipy import stats
from scipy.fft import fft, dct
import pywt
from sklearn.preprocessing import LabelEncoder
np.set_printoptions(threshold=sys.maxsize)
from matplotlib.backends.backend_pdf import PdfPages
import os
from pyts.approximation import PiecewiseAggregateApproximation as PAA
from scipy.fftpack import idct

def generate_random_vectors(n, r):
    random_vectors = np.random.normal(0, 1, size=(r, n))
    return random_vectors

def MINE(data,R,R_inv):

  prod = np.matmul(data,R)
  bitmap = np.where(prod < 0, 0, 1)
  recon = np.matmul(bitmap,R_inv)
  return recon

def plot_confidence_interval(scores,method,stride,compression,type):
    # compute mean silhouette score and confidence interval
    mean_score = np.mean(scores)
    ci = stats.t.interval(0.95, len(scores)-1, loc=mean_score, scale=stats.sem(scores))

    # 2D array with the lower and upper bounds of the confidence interval
    yerr = np.array([[mean_score-ci[0]], [ci[1]-mean_score]])

    # create the figure and axis objects
    fig, ax = plt.subplots()

    # plot the data with error bars
    ax.plot(scores, marker='o')
    ax.errorbar(x=range(len(scores)), y=scores, yerr=yerr, fmt='none', ecolor='r')

    # set the axis labels and title
    ax.set_xlabel('Subset of features')

    if type == 'SC' :
     ax.set_ylabel('ACCURACY score')
     if method == 'RAW':
      ax.set_title(f'ACCURACY scores with 95% confidence interval\n M={method} , W= {stride} : [{ci[0]:.5f}, {ci[1]:.5f}]')
     else:
      ax.set_title(f'ACCURACY scores with 95% confidence interval\n M={method} , W= {stride}, C= {compression} : [{ci[0]:.5f}, {ci[1]:.5f}]')


    if type == 'RMSE' :
     ax.set_ylabel('F1 score')
     if method == 'RAW':
      ax.set_title(f'F1 scores with 95% confidence interval\n M={method} , W= {stride} : [{ci[0]:.5f}, {ci[1]:.5f}]')
     else:
      ax.set_title(f'F1 scores with 95% confidence interval\n M={method} , W= {stride}, C= {compression} : [{ci[0]:.5f}, {ci[1]:.5f}]')
    # return the figure object
    return fig

def plot_score_confidence_interval(data,window_size,compression):
    fig, axs = plt.subplots(1, 5, figsize=(20, 4), sharey=True)  # Adjust the figure size as needed

    colors = ['b', 'g', 'r', 'c', 'm']  # Colors for each method

    #y_axis_limits = (-5, 5)  # limits

    for i, (scores, method) in enumerate(data):
        ax = axs[i]
        n = len(scores)
        x = np.arange(n) + 1
        y = np.array(scores)

        # Identify and count outliers based on the limits
        outliers = np.where((y < -5) | (y > 5))[0]
        num_outliers = len(outliers)

        # Exclude outliers from the data
        filtered_scores = np.delete(y, outliers)
        filtered_x = np.delete(x, outliers)

        mean = np.mean(filtered_scores)
        # Calculate the confidence interval
        ci = stats.t.interval(0.95, len(filtered_scores), loc=mean, scale=stats.sem(filtered_scores))
        # Plot the non-outlier data points and mean
        ax.plot(filtered_x, filtered_scores, 'o', markersize=4, color=colors[i])
        ax.plot(x, [mean] * n, '--', color=colors[i])

        fig.suptitle(f'ACCURACY scores with 95% confidence interval // W= {window_size}, C= {compression} ')

        ax.set_xlabel('Window')
        ax.set_ylabel('Score')
        ax.set_title(f'{method} : [{ci[0]:.5f}, {ci[1]:.5f}] ')
        ax.grid(True)

        # Set the y-axis limits to the predefined range
        #ax.set_ylim(y_axis_limits)

        # Add the number of outliers as text in the top right corner
        ax.text(0.85, 0.9, f'Outliers: {num_outliers}', transform=ax.transAxes, fontsize=10, color='red', ha='right')

    return fig

def plot_F1_confidence_interval(data,window_size,compression):
    fig, axs = plt.subplots(1, 5, figsize=(20, 4), sharey=True)  # Adjust the figure size as needed

    colors = ['b', 'g', 'r', 'c', 'm']  # Colors for each method

    #y_axis_limits = (-5, 5) # limits

    for i, (scores, method) in enumerate(data):
        ax = axs[i]
        n = len(scores)
        x = np.arange(n) + 1
        y = np.array(scores)
        # Identify and count outliers based on the limits
        outliers = np.where((y < -5) | (y > 5))[0]
        num_outliers = len(outliers)

        # Exclude outliers from the data
        filtered_scores = np.delete(y, outliers)
        filtered_x = np.delete(x, outliers)

        mean = np.mean(filtered_scores)
        # Calculate the confidence interval
        ci = stats.t.interval(0.95, len(filtered_scores), loc=mean, scale=stats.sem(filtered_scores))

        # Plot the non-outlier data points and mean
        ax.plot(filtered_x, filtered_scores, 'o', markersize=4, color=colors[i])
        ax.plot(x, [mean] * n, '--', color=colors[i])

        fig.suptitle(f'F1 scores with 95% confidence interval // W= {window_size}, C= {compression} ')

        ax.set_xlabel('Window')
        ax.set_ylabel('Score')
        ax.set_title(f'{method} : [{ci[0]:.5f}, {ci[1]:.5f}]')
        ax.grid(True)

        # Set the y-axis limits
        #ax.set_ylim(y_axis_limits)

        # Add the number of outliers as text in the top right corner
        ax.text(0.85, 0.9, f'Outliers: {num_outliers}', transform=ax.transAxes, fontsize=10, color='red', ha='right')

    return fig


# Load data
df = pd.read_csv('/content/drive/MyDrive/pump_sensor2.txt', delimiter=',')

# BROKEN,NORMAL,RECOVERING -> 0,0.5,1
le = LabelEncoder()
df.iloc[:, -1] = le.fit_transform(df.iloc[:, -1])
max_label = df.iloc[:, -1].max()
df.iloc[:, -1] = df.iloc[:, -1] / max_label * 1.0
# Discard the first row + first two columns
df = df.iloc[:, 2:]
data = df.to_numpy(dtype='float')
# Split  features (X) and target (y)
X = data[:, :-1]
#print(X)
y = data[:, -1]
#print(y[0])
# Fill Nan values based on the mean of each sensor
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X = imputer.fit_transform(X)
# Select 1000 0.5 kai 1 labels
label_05_indices = np.where(y == 0.5)[0]
label_1_indices = np.where(y == 1)[0]
label_05_indices = np.random.choice(label_05_indices, size=1000, replace=False)
label_1_indices = np.random.choice(label_1_indices, size=1000, replace=False)
# Concatenate + shuffle
indices = np.concatenate((label_05_indices, label_1_indices))
np.random.seed(123)   #Gia idio dataset shuffle se ola ta algorithms
np.random.shuffle(indices)
X= X[indices]
y= y[indices]
y[y == 0.5] = 0

# window size, etc.
window_sizes = [16, 32, 64, 128]
compressions = [4, 8, 16]
methods = ['DFT','DCT', 'DWT','PAA','MINE']

#file for storing
folder_name = f"Neural Network PUMP Measurements"
if not os.path.exists(folder_name):
   os.makedirs(folder_name)

raw_folder_name = f"RAW DATA"
if not os.path.exists(os.path.join(folder_name,raw_folder_name)):
   os.makedirs(os.path.join(folder_name,raw_folder_name))
pdf_file = os.path.join(folder_name,raw_folder_name, 'plots.pdf')

with PdfPages(pdf_file, 'a') as pdf:
  for window_size in window_sizes:

     # lists to store metrics for each window
     f1_list = []
     accuracy_list = []
     num =int( window_size+window_size/4)

     # Iterate over the windows
     for i in range(0, len(X)-window_size*2+1, window_size):

          # Split the data into training and testing sets
          X_train = X[i:i+window_size]
          X_test = X[i+window_size:i+num]
          y_train = y[i:i+window_size]
          y_test = y[i+window_size:i+num]
          #print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

          # Data scaling
          sc = MinMaxScaler()
          X_train_scaled = sc.fit_transform(X_train)
          X_test_scaled = sc.transform(X_test)

          #print(X_train_scaled[0], X_test_scaled[0], y_train_scaled[0], y_test_scaled[0])

          # model
          model = Sequential()
          model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
          model.add(Dropout(0.2))
          model.add(Dense(32, activation='relu'))
          model.add(Dropout(0.2))
          model.add(Dense(3, activation='softmax'))
          model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

          # Train model
          es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
          history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=50, batch_size = window_size , callbacks=[es])

          # Predict on test data
          y_pred_probs = model.predict(X_test_scaled)
          y_pred = y_pred_probs.argmax(axis=-1)
          # Calculate accuracy and F1 score
          accuracy = accuracy_score(y_test, y_pred)
          f1 = f1_score(y_test, y_pred, average='macro')
          accuracy_list.append(accuracy)
          f1_list.append(f1)

     #store plots
     methd = 'RAW'
     comprsn = 0
     fig = plot_confidence_interval(accuracy_list,methd,window_size ,comprsn,'SC') #plot function call
     pdf.savefig(fig)
     plt.close(fig)

     fig2 = plot_confidence_interval(f1_list,methd,window_size ,comprsn,'RMSE') #plot function call
     pdf.savefig(fig2)
     plt.close(fig2)

     # create a file name based on the method, subset index, stride, and compression
     avg_accuracy = np.mean(accuracy_list)
     file_name = f"Window size({window_size}) - accuracy-scores.txt"
     with open(os.path.join(folder_name,raw_folder_name, file_name), 'w+') as f:
              f.write(f"Average accuracy Score: {avg_accuracy}\n")
              content = str(accuracy_list)
              f.write(content)
              f.close()

     avg_f1 = np.mean(f1_list)
     file_name = f"Window size({window_size}) - f1 scores).txt"
     with open(os.path.join(folder_name,raw_folder_name, file_name), 'w+') as f:
              f.write(f"Average f1 Score: {avg_f1}\n")
              content = str(f1_list)
              f.write(content)
              f.close()

for window_size in window_sizes:

    #file for storing
    stride_folder_name = f"stride({window_size})"
    if not os.path.exists(os.path.join(folder_name,stride_folder_name)):
        os.makedirs(os.path.join(folder_name,stride_folder_name))

    for compression in compressions:

        #vector and inverse vector arrays for our algorithm
        n = 64*int(window_size/compression)  # Dimension of each random vector
        r = 51  # Number of random vectors to generate/rows
        R = generate_random_vectors(n, r)
        R_inv= np.linalg.pinv(R)

        #files for storing measurements
        compression_folder_name = f"compression({compression})"
        if not os.path.exists(os.path.join(folder_name,stride_folder_name, compression_folder_name)):
            os.makedirs(os.path.join(folder_name,stride_folder_name, compression_folder_name))

        #files for storing plots
        plots_dir = os.path.join(folder_name,stride_folder_name, compression_folder_name, 'plots')
        os.makedirs(plots_dir, exist_ok=True)
        pdf_file = os.path.join(plots_dir, 'plots.pdf')

        with PdfPages(pdf_file, 'a') as pdf:
            results1 = []
            results2 = []
            for method in methods:

                slices = window_size // compression

                # lists to store metrics for each window
                f1_list = []
                accuracy_list = []
                num =int( window_size+window_size/4)

                # Iterate over the windows
                for i in range(0, len(X)-window_size*2+1, window_size):

                   # Split the data into training and testing sets
                   X_train = X[i:i+window_size]
                   X_test = X[i+window_size:i+num]
                   y_train = y[i:i+window_size]
                   y_test = y[i+window_size:i+num]
                 #  print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

                   # Data scaling
                   sc = MinMaxScaler()
                   X_train_scaled = sc.fit_transform(X_train)
                   X_test_scaled = sc.transform(X_test)

                   if method == 'DFT':

                       #array to store the restored data
                       compressed_X_train_scaled = np.zeros_like(X_train_scaled)

                       for i in range(window_size):
                          # Compute abs DFT of each row
                          dft_X_train_scaled  =  np.fft.fft(X_train_scaled[i])
                          # Sort the DFT coefficients along each row by their magnitude
                          sorted_indices = np.argsort(-np.abs(dft_X_train_scaled))[:slices]
                          sorted_dft_X_train_scaled = dft_X_train_scaled[sorted_indices]
                          # Keep  top  coeff
                          top__dft_X_train_scaled = sorted_dft_X_train_scaled[:slices]
                          #reconstruct the compressed dataset
                          compressed_X_train_scaled[i] = np.fft.ifft(top__dft_X_train_scaled,51).real

                       #array to store the restored data
                       compressed_X_test_scaled = np.zeros_like(X_test_scaled)

                       for i in range(int(window_size/4)):
                          # Compute abs DFT of each row
                          dft_X_test_scaled =  np.fft.fft(X_test_scaled[i])
                          # Sort the DFT coefficients along each row by their magnitude
                          sorted_indices = np.argsort(np.abs(dft_X_test_scaled))[::-1][:slices]
                          sorted_dft_X_test_scaled = dft_X_test_scaled[sorted_indices]
                          # Keep  top  coeff
                          top__dft_X_test_scaled = sorted_dft_X_test_scaled[:slices]
                          #reconstruct the compressed dataset
                          compressed_X_test_scaled[i] = np.fft.ifft(top__dft_X_test_scaled,51).real


                   elif method == 'DCT':

                       #array to store the restored data
                       compressed_X_train_scaled = np.zeros_like(X_train_scaled)

                       for i in range(window_size):
                          # Compute abs DCT of each row
                          dct_X_train_scaled  =  dct(X_train_scaled[i])
                          # Sort the DCT coefficients along each row by their magnitude
                          sorted_indices = np.argsort(-np.abs(dct_X_train_scaled))[:slices]
                          sorted_dct_X_train_scaled = dct_X_train_scaled[sorted_indices]
                          # Keep  top  coeff
                          top__dct_X_train_scaled = sorted_dct_X_train_scaled[:slices]
                          #reconstruct the compressed dataset
                          compressed_X_train_scaled[i] = idct(top__dct_X_train_scaled ,type = 2, n = 51).real

                       #array to store the restored data
                       compressed_X_test_scaled = np.zeros_like(X_test_scaled)

                       for i in range(int(window_size/4)):
                          # Compute abs DCT of each row
                          dct_X_test_scaled =  dct(X_test_scaled[i])
                          # Sort the DCT coefficients along each row by their magnitude
                          sorted_indices = np.argsort(-np.abs(dct_X_test_scaled))[:slices]
                          sorted_dct_X_test_scaled = dct_X_test_scaled[sorted_indices]
                          # Keep  top  coeff
                          top__dct_X_test_scaled = sorted_dct_X_test_scaled[:slices]
                          #reconstruct the compressed dataset
                          compressed_X_test_scaled[i] = idct(top__dct_X_test_scaled ,type = 2 , n = 51).real

                   elif method == 'DWT':

                      #array to store the restored data
                      compressed_X_train_scaled = np.zeros_like(X_train_scaled)
                      compressed_X_train_scaled = np.pad(compressed_X_train_scaled, ((0, 0), (0, 1)), 'constant', constant_values=0)
                      for i in range(window_size):
                          # Apply DWT to each row using 'db1' wavelet
                          cA, cD = pywt.dwt(X_train_scaled[i], 'db1')
                          # Sort
                          sorted_cD_subset_data = np.zeros_like(cD) #initialize storage array
                          sorted_indices = np.argsort(-np.abs(cD))[:slices]
                          sorted_cD_subset_data[sorted_indices] = cD[sorted_indices]
                          # Perform inverse DWT to restore the row
                          compressed_X_train_scaled[i] = pywt.idwt(cA, sorted_cD_subset_data, 'db1')

                      #array to store the restored data
                      compressed_X_test_scaled = np.zeros_like(X_test_scaled)
                      compressed_X_test_scaled = np.pad(compressed_X_test_scaled, ((0, 0), (0, 1)), 'constant', constant_values=0)
                      for i in range(int(window_size/4)):
                          # Apply DWT to each row using 'db1' wavelet
                          cA, cD = pywt.dwt(X_test_scaled[i], 'db1')
                          # Sort
                          sorted_cD_subset_data = np.zeros_like(cD) #initialize storage array
                          sorted_indices = np.argsort(-np.abs(cD))[:slices]
                          sorted_cD_subset_data[sorted_indices] = cD[sorted_indices]
                          # Perform inverse DWT to restore the row
                          compressed_X_test_scaled[i] = pywt.idwt(cA, sorted_cD_subset_data, 'db1')


                   elif method == 'PAA':
                      # Apply PAA along the rows of the array
                      paa = PAA(window_size = compression)
                      compressed_X_train_scaled = paa.fit_transform(X_train_scaled)
                      compressed_X_test_scaled = paa.fit_transform(X_test_scaled)

                   elif method == 'MINE':

                      #array to store the restored data
                      compressed_X_train_scaled = np.zeros_like(X_train_scaled)

                      for i in range(window_size):
                        row = X_train_scaled[i]
                        # Apply my algorithm along the rows of the array
                        compressed_X_train_scaled[i] = MINE(row,R,R_inv)

                      #array to store the restored data
                      compressed_X_test_scaled = np.zeros_like(X_test_scaled)
                      for i in range(int(window_size/4)):
                        row = X_test_scaled[i]
                        # Apply my algorithm along the rows of the array
                        compressed_X_test_scaled[i] = MINE(row,R,R_inv)

                   # model
                   model = Sequential()
                   model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
                   model.add(Dropout(0.2))
                   model.add(Dense(32, activation='relu'))
                   model.add(Dropout(0.2))
                   model.add(Dense(3, activation='softmax'))
                   model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

                   # Train model
                   es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
                   history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=50, batch_size=window_size, callbacks=[es])

                   # Predict on test data
                   y_pred_probs = model.predict(X_test_scaled)
                   y_pred = y_pred_probs.argmax(axis=-1)
                   # Calculate accuracy and F1 score
                   accuracy = accuracy_score(y_test, y_pred)
                   f1 = f1_score(y_test, y_pred, average='macro')
                   accuracy_list.append(accuracy)
                   f1_list.append(f1)

                results1.append((accuracy_list, method))
                results2.append((f1_list, method))

                # create a file name based on the method, subset index, stride, and compression
                avg_accuracy = np.mean(accuracy_list)
                file_name = f"{method}_window size({window_size})_compression({compression} - ACCURACY SCORES).txt"
                with open(os.path.join(folder_name,stride_folder_name, compression_folder_name, file_name), 'w+') as f:
                   f.write(f"Average accuracy Score: {avg_accuracy}\n")
                   content = str(accuracy_list)
                   f.write(content)
                   f.close()

                avg_f1 = np.mean(f1_list)
                file_name = f"{method}_window size({window_size})_compression({compression} - f1 SCORES).txt"
                with open(os.path.join(folder_name,stride_folder_name, compression_folder_name, file_name), 'w+') as f:
                   f.write(f"Average f1 Score: {avg_f1}\n")
                   content = str(f1_list)
                   f.write(content)
                   f.close()
            #store plots
            fig = plot_score_confidence_interval(results1,window_size,compression) #plot function call
            pdf.savefig(fig)
            plt.close(fig)
            fig = plot_F1_confidence_interval(results2,window_size,compression) #plot function call
            pdf.savefig(fig)
            plt.close(fig)
# Out:
# <ipython-input-3-0d19e58f4b9c>:160: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:, -1] = le.fit_transform(df.iloc[:, -1])
# Epoch 1/50
# 1/1 [==============================] - 3s 3s/step - loss: 1.1440 - accuracy: 0.3200 - val_loss: 1.0522 - val_accuracy: 0.5714
# Epoch 2/50
# 1/1 [==============================] - 0s 142ms/step - loss: 1.0923 - accuracy: 0.4800 - val_loss: 1.0043 - val_accuracy: 0.5714
# Epoch 3/50
# 1/1 [==============================] - 0s 83ms/step - loss: 1.0406 - accuracy: 0.4000 - val_loss: 0.9619 - val_accuracy: 0.8571
# Epoch 4/50
# 1/1 [==============================] - 0s 136ms/step - loss: 1.0723 - accuracy: 0.3600 - val_loss: 0.9287 - val_accuracy: 0.8571
# Epoch 5/50
# 1/1 [==============================] - 0s 109ms/step - loss: 0.9907 - accuracy: 0.4400 - val_loss: 0.8965 - val_accuracy: 0.8571
# Epoch 6/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.9617 - accuracy: 0.4000 - val_loss: 0.8675 - val_accuracy: 0.8571
# Epoch 7/50
# 1/1 [==============================] - 0s 99ms/step - loss: 0.8851 - accuracy: 0.7200 - val_loss: 0.8406 - val_accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 125ms/step - loss: 0.9368 - accuracy: 0.4800 - val_loss: 0.8140 - val_accuracy: 1.0000
# Epoch 9/50
# 1/1 [==============================] - 0s 152ms/step - loss: 0.8226 - accuracy: 0.8000 - val_loss: 0.7881 - val_accuracy: 1.0000
# Epoch 10/50
# 1/1 [==============================] - 0s 161ms/step - loss: 0.8289 - accuracy: 0.6400 - val_loss: 0.7647 - val_accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 101ms/step - loss: 0.8072 - accuracy: 0.7200 - val_loss: 0.7433 - val_accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 0s 149ms/step - loss: 0.8111 - accuracy: 0.7200 - val_loss: 0.7212 - val_accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 192ms/step - loss: 0.7531 - accuracy: 0.7200 - val_loss: 0.7006 - val_accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 174ms/step - loss: 0.7635 - accuracy: 0.7600 - val_loss: 0.6799 - val_accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 159ms/step - loss: 0.7582 - accuracy: 0.6400 - val_loss: 0.6598 - val_accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 126ms/step - loss: 0.7172 - accuracy: 0.7600 - val_loss: 0.6391 - val_accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1760 - accuracy: 0.2800 - val_loss: 1.0448 - val_accuracy: 0.2857
# Epoch 3/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0733 - accuracy: 0.5200 - val_loss: 0.9537 - val_accuracy: 0.8571
# Epoch 4/50
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0384 - accuracy: 0.6400 - val_loss: 0.8793 - val_accuracy: 0.8571
# Epoch 5/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9985 - accuracy: 0.4800 - val_loss: 0.8236 - val_accuracy: 1.0000
# Epoch 6/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8933 - accuracy: 0.6000 - val_loss: 0.7871 - val_accuracy: 0.8571
# Epoch 7/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8338 - accuracy: 0.6800 - val_loss: 0.7597 - val_accuracy: 0.8571
# Epoch 8/50
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8066 - accuracy: 0.7600 - val_loss: 0.7370 - val_accuracy: 0.8571
# Epoch 9/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8035 - accuracy: 0.6000 - val_loss: 0.7151 - val_accuracy: 0.8571
# Epoch 10/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6774 - accuracy: 0.7600 - val_loss: 0.6925 - val_accuracy: 0.8571
# Epoch 11/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.7388 - accuracy: 0.7600 - val_loss: 0.6691 - val_accuracy: 0.8571
# Epoch 12/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.7224 - accuracy: 0.7200 - val_loss: 0.6464 - val_accuracy: 0.8571
# Epoch 13/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6356 - accuracy: 0.8000 - val_loss: 0.6224 - val_accuracy: 0.8571
# Epoch 14/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6195 - accuracy: 0.7600 - val_loss: 0.5955 - val_accuracy: 0.8571
# Epoch 15/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6680 - accuracy: 0.7600 - val_loss: 0.5690 - val_accuracy: 0.8571
# Epoch 16/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5351 - accuracy: 0.8000 - val_loss: 0.5434 - val_accuracy: 0.8571
# Epoch 17/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4977 - accuracy: 0.8800 - val_loss: 0.5186 - val_accuracy: 0.8571
# Epoch 18/50
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5576 - accuracy: 0.8800 - val_loss: 0.4948 - val_accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5898 - accuracy: 0.8000 - val_loss: 0.4713 - val_accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4915 - accuracy: 0.8400 - val_loss: 0.4488 - val_accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4659 - accuracy: 0.8800 - val_loss: 0.4277 - val_accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4630 - accuracy: 0.8800 - val_loss: 0.4080 - val_accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4479 - accuracy: 0.9200 - val_loss: 0.3899 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3971 - accuracy: 0.9200 - val_loss: 0.3719 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4524 - accuracy: 0.9200 - val_loss: 0.3536 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4562 - accuracy: 0.9200 - val_loss: 0.3361 - val_accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5158 - accuracy: 0.8400 - val_loss: 0.3189 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4369 - accuracy: 0.8400 - val_loss: 0.3024 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3780 - accuracy: 0.8800 - val_loss: 0.2871 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3288 - accuracy: 0.9200 - val_loss: 0.2727 - val_accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3879 - accuracy: 0.9200 - val_loss: 0.2579 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3143 - accuracy: 0.8800 - val_loss: 0.2432 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2833 - accuracy: 0.9200 - val_loss: 0.2291 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3272 - accuracy: 0.9200 - val_loss: 0.2164 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2163 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2820 - accuracy: 0.9600 - val_loss: 0.1939 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2204 - accuracy: 1.0000 - val_loss: 0.1836 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2575 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2195 - accuracy: 1.0000 - val_loss: 0.1643 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2321 - accuracy: 0.9600 - val_loss: 0.1551 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1605 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2383 - accuracy: 0.9600 - val_loss: 0.1381 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2314 - accuracy: 0.9600 - val_loss: 0.1302 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1740 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1863 - accuracy: 0.9600 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2189 - accuracy: 0.9200 - val_loss: 0.1094 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1494 - accuracy: 0.9600 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1676 - accuracy: 0.9600 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.
# 1/1 [==============================] - 0s 75ms/step - loss: 0.7230 - accuracy: 0.8137 - val_loss: 0.7505 - val_accuracy: 0.7692
# Epoch 15/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7146 - accuracy: 0.7647 - val_loss: 0.7284 - val_accuracy: 0.6923
# Epoch 16/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6436 - accuracy: 0.8529 - val_loss: 0.7081 - val_accuracy: 0.6538
# Epoch 17/50
# ...
# Epoch 38/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1951 - accuracy: 0.9902 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2171 - accuracy: 0.9804 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1921 - accuracy: 0.9804 - val_loss: 0.1081 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2227 - accuracy: 0.9412 - val_loss: 0.1011 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1935 - accuracy: 0.9510 - val_loss: 0.0946 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1996 - accuracy: 0.9510 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1778 - accuracy: 0.9706 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1890 - accuracy: 0.9510 - val_loss: 0.0769 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1676 - accuracy: 0.9804 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1659 - accuracy: 0.9804 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1418 - accuracy: 0.9902 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1411 - accuracy: 0.9706 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1219 - accuracy: 0.9706 - val_loss: 0.0533 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 115ms/step
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9065 - accuracy: 0.6176 - val_loss: 0.7977 - val_accuracy: 0.8462
# Epoch 2/50
# 1/1 [==============================] - 0s 96ms/step - loss: 0.8737 - accuracy: 0.5784 - val_loss: 0.7529 - val_accuracy: 0.9231
# Epoch 3/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.8347 - accuracy: 0.6471 - val_loss: 0.7112 - val_accuracy: 0.9615
# Epoch 4/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7814 - accuracy: 0.7745 - val_loss: 0.6719 - val_accuracy: 1.0000
# Epoch 5/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.7131 - accuracy: 0.7451 - val_loss: 0.6345 - val_accuracy: 1.0000
# Epoch 6/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6858 - accuracy: 0.8039 - val_loss: 0.6003 - val_accuracy: 1.0000
# Epoch 7/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6431 - accuracy: 0.8235 - val_loss: 0.5689 - val_accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 83ms/step - loss: 0.6175 - accuracy: 0.8824 - val_loss: 0.5399 - val_accuracy: 1.0000
# Epoch 9/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.5798 - accuracy: 0.8725 - val_loss: 0.5133 - val_accuracy: 1.0000
# Epoch 10/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6311 - accuracy: 0.8039 - val_loss: 0.4892 - val_accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5153 - accuracy: 0.8824 - val_loss: 0.4671 - val_accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.5359 - accuracy: 0.8627 - val_loss: 0.4461 - val_accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.5105 - accuracy: 0.8627 - val_loss: 0.4266 - val_accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4705 - accuracy: 0.8824 - val_loss: 0.4077 - val_accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4128 - accuracy: 0.9216 - val_loss: 0.3903 - val_accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 87ms/step - loss: 0.4288 - accuracy: 0.9216 - val_loss: 0.3736 - val_accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4380 - accuracy: 0.8529 - val_loss: 0.3578 - val_accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 83ms/step - loss: 0.4555 - accuracy: 0.8529 - val_loss: 0.3423 - val_accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 86ms/step - loss: 0.3912 - accuracy: 0.8824 - val_loss: 0.3268 - val_accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4404 - accuracy: 0.8627 - val_loss: 0.3112 - val_accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3655 - accuracy: 0.9216 - val_loss: 0.2962 - val_accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 97ms/step - loss: 0.3275 - accuracy: 0.9510 - val_loss: 0.2823 - val_accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3830 - accuracy: 0.9216 - val_loss: 0.2687 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3286 - accuracy: 0.9314 - val_loss: 0.2556 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.2982 - accuracy: 0.9804 - val_loss: 0.2435 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 96ms/step - loss: 0.2912 - accuracy: 0.9314 - val_loss: 0.2326 - val_accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3078 - accuracy: 0.9510 - val_loss: 0.2220 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 97ms/step - loss: 0.2868 - accuracy: 0.9216 - val_loss: 0.2115 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2640 - accuracy: 0.9608 - val_loss: 0.2012 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2563 - accuracy: 0.9804 - val_loss: 0.1910 - val_accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2566 - accuracy: 0.9706 - val_loss: 0.1810 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2704 - accuracy: 0.9314 - val_loss: 0.1712 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2283 - accuracy: 0.9608 - val_loss: 0.1618 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.2239 - accuracy: 0.9608 - val_loss: 0.1526 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 104ms/step - loss: 0.1816 - accuracy: 0.9706 - val_loss: 0.1434 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 102ms/step - loss: 0.2159 - accuracy: 0.9706 - val_loss: 0.1344 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2142 - accuracy: 0.9412 - val_loss: 0.1253 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1679 - accuracy: 0.9902 - val_loss: 0.1171 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2212 - accuracy: 0.9510 - val_loss: 0.1086 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1406 - accuracy: 0.9902 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1555 - accuracy: 0.9608 - val_loss: 0.0942 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1666 - accuracy: 0.9608 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1411 - accuracy: 0.9804 - val_loss: 0.0812 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1552 - accuracy: 0.9608 - val_loss: 0.0753 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1325 - accuracy: 0.9902 - val_loss: 0.0705 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1194 - accuracy: 0.9804 - val_loss: 0.0662 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1258 - accuracy: 0.9804 - val_loss: 0.0628 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1068 - accuracy: 0.9804 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1091 - accuracy: 0.9902 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0811 - accuracy: 0.9902 - val_loss: 0.0536 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 145ms/step
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.9359 - accuracy: 0.4216 - val_loss: 0.7929 - val_accuracy: 0.6154
# Epoch 2/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.8744 - accuracy: 0.4510 - val_loss: 0.7492 - val_accuracy: 0.8462
# Epoch 3/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.7994 - accuracy: 0.5980 - val_loss: 0.7124 - val_accuracy: 0.7308
# Epoch 4/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8058 - accuracy: 0.6471 - val_loss: 0.6835 - val_accuracy: 0.6154
# Epoch 5/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7490 - accuracy: 0.5784 - val_loss: 0.6599 - val_accuracy: 0.6154
# Epoch 6/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.7267 - accuracy: 0.5882 - val_loss: 0.6408 - val_accuracy: 0.6154
# Epoch 7/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.7179 - accuracy: 0.5784 - val_loss: 0.6247 - val_accuracy: 0.6154
# Epoch 8/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6629 - accuracy: 0.6471 - val_loss: 0.6094 - val_accuracy: 0.6154
# Epoch 9/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6856 - accuracy: 0.5882 - val_loss: 0.5940 - val_accuracy: 0.6154
# Epoch 10/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6220 - accuracy: 0.6569 - val_loss: 0.5778 - val_accuracy: 0.6154
# Epoch 11/50
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6081 - accuracy: 0.6667 - val_loss: 0.5610 - val_accuracy: 0.6154
# Epoch 12/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6100 - accuracy: 0.6863 - val_loss: 0.5435 - val_accuracy: 0.6154
# Epoch 13/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5820 - accuracy: 0.6961 - val_loss: 0.5256 - val_accuracy: 0.6154
# Epoch 14/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5426 - accuracy: 0.7353 - val_loss: 0.5067 - val_accuracy: 0.6538
# Epoch 15/50
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5572 - accuracy: 0.6765 - val_loss: 0.4879 - val_accuracy: 0.7308
# Epoch 16/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5617 - accuracy: 0.7255 - val_loss: 0.4685 - val_accuracy: 0.7692
# Epoch 17/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5267 - accuracy: 0.7745 - val_loss: 0.4494 - val_accuracy: 0.8077
# Epoch 18/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4983 - accuracy: 0.8333 - val_loss: 0.4310 - val_accuracy: 0.8846
# Epoch 19/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5121 - accuracy: 0.7941 - val_loss: 0.4130 - val_accuracy: 0.8846
# Epoch 20/50
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4787 - accuracy: 0.8333 - val_loss: 0.3961 - val_accuracy: 0.8846
# Epoch 21/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4806 - accuracy: 0.8039 - val_loss: 0.3806 - val_accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4302 - accuracy: 0.8824 - val_loss: 0.3659 - val_accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4400 - accuracy: 0.8529 - val_loss: 0.3519 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4184 - accuracy: 0.9216 - val_loss: 0.3385 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3880 - accuracy: 0.9020 - val_loss: 0.3252 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3748 - accuracy: 0.9020 - val_loss: 0.3120 - val_accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 94ms/step - loss: 0.3558 - accuracy: 0.9314 - val_loss: 0.2987 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3251 - accuracy: 0.9510 - val_loss: 0.2852 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3107 - accuracy: 0.9412 - val_loss: 0.2715 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.3181 - accuracy: 0.9510 - val_loss: 0.2578 - val_accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 113ms/step - loss: 0.3199 - accuracy: 0.9412 - val_loss: 0.2447 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2487 - accuracy: 0.9608 - val_loss: 0.2322 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 90ms/step - loss: 0.2982 - accuracy: 0.9118 - val_loss: 0.2204 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 93ms/step - loss: 0.2772 - accuracy: 0.9314 - val_loss: 0.2093 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2376 - accuracy: 0.9608 - val_loss: 0.1989 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 96ms/step - loss: 0.2562 - accuracy: 0.9412 - val_loss: 0.1887 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 88ms/step - loss: 0.2512 - accuracy: 0.9412 - val_loss: 0.1790 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2156 - accuracy: 0.9608 - val_loss: 0.1695 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2004 - accuracy: 0.9804 - val_loss: 0.1602 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2243 - accuracy: 0.9804 - val_loss: 0.1515 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1721 - accuracy: 0.9902 - val_loss: 0.1435 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1757 - accuracy: 0.9804 - val_loss: 0.1361 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1592 - accuracy: 0.9902 - val_loss: 0.1293 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1687 - accuracy: 0.9706 - val_loss: 0.1229 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1468 - accuracy: 0.9804 - val_loss: 0.1169 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1367 - accuracy: 0.9804 - val_loss: 0.1114 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1515 - accuracy: 0.9804 - val_loss: 0.1060 - val_accuracy: 0.9615
# Epoch 48/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1045 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1128 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1224 - accuracy: 0.9804 - val_loss: 0.0911 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 79ms/step
